# %%
from LGModels import *

# %%
W= Qs('x^3+x*y^2')
G = Grp(W,'J')
A = Am(G)
# Out:
# C23
# [y, x]
# FJRW ring for x^3 + x*y^2 with group generated by <(1/3, 1/3)>.
# Dimension:   4
# Basis:
#   [1]  e_(1/3, 1/3)  Degree: 0    (0, 0)
#   [2]  ye_(0, 0)     Degree: 2/3  (1/3, 1/3)
#   [3]  xe_(0, 0)     Degree: 2/3  (1/3, 1/3)
#   [4]  e_(2/3, 2/3)  Degree: 4/3  (2/3, 2/3)

# %%
A.corr([A[1],A[2],A[2]])
# Out:
# -1/2

# %%
A.corr([A[2],A[2],A[2],A[2]])
# Out:
# 0

# %%
A.corr([A[2],A[2],A[2],A[4]])
# Out:
# ---------------------------------------------------------------------------
# CouldNotComputeException                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 A.corr([A[Integer(2)],A[Integer(2)],A[Integer(2)],A[Integer(4)]])
#
# File ~/Desktop/SageCode/LGCode/FJRW.py:1071, in FJRWRing.corr(self, a, verbose, g, deg_Witten_already_tried, shortcut)
#    1068 X = CouldNotComputeException("The correlator could not be "
#    1069                              "computed for <%s>" % str(a)[1:-1])
#    1070 current_dict[key_a] = X
# -> 1071 raise X
#
# CouldNotComputeException: The correlator could not be computed for <ye_(0, 0), ye_(0, 0), ye_(0, 0), e_(2/3, 2/3)>
